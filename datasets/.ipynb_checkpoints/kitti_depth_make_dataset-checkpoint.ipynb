# %%
# 1. Import Module
import os, sys
import random
#import itertools
#import io
#import math
import pandas as pd
import numpy as np
import numpy
#import seaborn as sns
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import cv2
import pandas as pd
import math
import time

from tqdm import tqdm

from torchvision import datasets, transforms
from transformers import GLPNForDepthEstimation, GLPNFeatureExtractor
from PIL import Image

# %%
glp_kitti_preprocessing_data = pd.read_csv('./glp_kitti_preprocessing_data.csv')

# %%
glp_kitti_preprocessing_data
# Out:
#          filename   class       xmin       ymin        xmax       ymax  angle  \
# 0      000000.png  person  711.87683  151.95032   809.37300  308.49020  -0.20
# 1      000001.png     car  390.57785  181.78027   421.47256  200.24520   1.85
# 2      000002.png     car  655.78680  190.24402   698.48170  221.83864  -1.67
# 3      000003.png     car  612.12930  176.14651   729.66540  282.53200   1.55
# 4      000004.png     car  283.69547  184.47151   343.14720  211.07599   1.96
# ...           ...     ...        ...        ...         ...        ...    ...
# 31455  007480.png     car  804.09814  187.89252  1000.97565  272.06360   2.68
# 31456  007480.png     car  749.07380  175.12215   876.04650  229.95288  -0.33
# 31457  007480.png     car  355.50946  180.77954   467.92645  209.64455  -2.90
# 31458  007480.png     car  632.70330  178.27335   678.27924  215.49060  -1.69
# 31459  007480.png     car  612.24690  175.13939   633.75600  197.97005  -1.62
#
#         zloc weather
# 0       8.41   clone
# 1      58.49   clone
# 2      34.38   clone
# 3      13.22   clone
# 4      38.26   clone
# ...      ...     ...
# 31455  13.60   clone
# 31456  18.85   clone
# 31457  26.03   clone
# 31458  31.98   clone
# 31459  47.02   clone
#
# [31460 rows x 9 columns]

# %%
feature_extractor = GLPNFeatureExtractor.from_pretrained("vinvino02/glpn-kitti") # glpn-nyu2
model = GLPNForDepthEstimation.from_pretrained("vinvino02/glpn-kitti")
model.eval()
# Out:
# GLPNForDepthEstimation(
#   (glpn): GLPNModel(
#     (encoder): GLPNEncoder(
#       (patch_embeddings): ModuleList(
#         (0): GLPNOverlapPatchEmbeddings(
#           (proj): Conv2d(3, 64, kernel_size=(7, 7), stride=(4, 4), padding=(3, 3))
#           (layer_norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): GLPNOverlapPatchEmbeddings(
#           (proj): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (layer_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         )
#         (2): GLPNOverlapPatchEmbeddings(
#           (proj): Conv2d(128, 320, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (layer_norm): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#         )
#         (3): GLPNOverlapPatchEmbeddings(
#           (proj): Conv2d(320, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (block): ModuleList(
#         (0): ModuleList(
#           (0): GLPNLayer(
#             (layer_norm_1): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#             (attention): GLPNAttention(
#               (self): GLPNEfficientSelfAttention(
#                 (query): Linear(in_features=64, out_features=64, bias=True)
#                 (key): Linear(in_features=64, out_features=64, bias=True)
#                 (value): Linear(in_features=64, out_features=64, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (sr): Conv2d(64, 64, kernel_size=(8, 8), stride=(8, 8))
#                 (layer_norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#               )
#               (output): GLPNSelfOutput(
#                 (dense): Linear(in_features=64, out_features=64, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (drop_path): Identity()
#             (layer_norm_2): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#             (mlp): GLPNMixFFN(
#               (dense1): Linear(in_features=64, out_features=256, bias=True)
#               (dwconv): GLPNDWConv(
#                 (dwconv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256)
#               )
#               (intermediate_act_fn): GELUActivation()
#               (dense2): Linear(in_features=256, out_features=64, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (1): GLPNLayer(
#             (layer_norm_1): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#             (attention): GLPNAttention(
#               (self): GLPNEfficientSelfAttention(
#                 (query): Linear(in_features=64, out_features=64, bias=True)
#                 (key): Linear(in_features=64, out_features=64, bias=True)
#                 (value): Linear(in_features=64, out_features=64, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (sr): Conv2d(64, 64, kernel_size=(8, 8), stride=(8, 8))
#                 (layer_norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#               )
#               (output): GLPNSelfOutput(
#                 (dense): Linear(in_features=64, out_features=64, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (drop_path): GLPNDropPath()
#             (layer_norm_2): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#             (mlp): GLPNMixFFN(
#               (dense1): Linear(in_features=64, out_features=256, bias=True)
#               (dwconv): GLPNDWConv(
#                 (dwconv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256)
#               )
#               (intermediate_act_fn): GELUActivation()
#               (dense2): Linear(in_features=256, out_features=64, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (2): GLPNLayer(
#             (layer_norm_1): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#             (attention): GLPNAttention(
#               (self): GLPNEfficientSelfAttention(
#                 (query): Linear(in_features=64, out_features=64, bias=True)
#                 (key): Linear(in_features=64, out_features=64, bias=True)
#                 (value): Linear(in_features=64, out_features=64, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (sr): Conv2d(64, 64, kernel_size=(8, 8), stride=(8, 8))
#                 (layer_norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#               )
#               (output): GLPNSelfOutput(
#                 (dense): Linear(in_features=64, out_features=64, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (drop_path): GLPNDropPath()
#             (layer_norm_2): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#             (mlp): GLPNMixFFN(
#               (dense1): Linear(in_features=64, out_features=256, bias=True)
#               (dwconv): GLPNDWConv(
#                 (dwconv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256)
#               )
#               (intermediate_act_fn): GELUActivation()
#               (dense2): Linear(in_features=256, out_features=64, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#         )
#         (1): ModuleList(
#           (0): GLPNLayer(
#             (layer_norm_1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#             (attention): GLPNAttention(
#               (self): GLPNEfficientSelfAttention(
#                 (query): Linear(in_features=128, out_features=128, bias=True)
#                 (key): Linear(in_features=128, out_features=128, bias=True)
#                 (value): Linear(in_features=128, out_features=128, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (sr): Conv2d(128, 128, kernel_size=(4, 4), stride=(4, 4))
#                 (layer_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#               )
#               (output): GLPNSelfOutput(
#                 (dense): Linear(in_features=128, out_features=128, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (drop_path): GLPNDropPath()
#             (layer_norm_2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#             (mlp): GLPNMixFFN(
#               (dense1): Linear(in_features=128, out_features=512, bias=True)
#               (dwconv): GLPNDWConv(
#                 (dwconv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#               )
#               (intermediate_act_fn): GELUActivation()
#               (dense2): Linear(in_features=512, out_features=128, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (1): GLPNLayer(
#             (layer_norm_1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#             (attention): GLPNAttention(
#               (self): GLPNEfficientSelfAttention(
#                 (query): Linear(in_features=128, out_features=128, bias=True)
#                 (key): Linear(in_features=128, out_features=128, bias=True)
#                 (value): Linear(in_features=128, out_features=128, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (sr): Conv2d(128, 128, kernel_size=(4, 4), stride=(4, 4))
#                 (layer_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#               )
#               (output): GLPNSelfOutput(
#                 (dense): Linear(in_features=128, out_features=128, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (drop_path): GLPNDropPath()
#             (layer_norm_2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#             (mlp): GLPNMixFFN(
#               (dense1): Linear(in_features=128, out_features=512, bias=True)
#               (dwconv): GLPNDWConv(
#                 (dwconv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#               )
#               (intermediate_act_fn): GELUActivation()
#               (dense2): Linear(in_features=512, out_features=128, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (2): GLPNLayer(
#             (layer_norm_1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#             (attention): GLPNAttention(
#               (self): GLPNEfficientSelfAttention(
#                 (query): Linear(in_features=128, out_features=128, bias=True)
#                 (key): Linear(in_features=128, out_features=128, bias=True)
#                 (value): Linear(in_features=128, out_features=128, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (sr): Conv2d(128, 128, kernel_size=(4, 4), stride=(4, 4))
#                 (layer_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#               )
#               (output): GLPNSelfOutput(
#                 (dense): Linear(in_features=128, out_features=128, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (drop_path): GLPNDropPath()
#             (layer_norm_2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#             (mlp): GLPNMixFFN(
#               (dense1): Linear(in_features=128, out_features=512, bias=True)
#               (dwconv): GLPNDWConv(
#                 (dwconv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#               )
#               (intermediate_act_fn): GELUActivation()
#               (dense2): Linear(in_features=512, out_features=128, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (3): GLPNLayer(
#             (layer_norm_1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#             (attention): GLPNAttention(
#               (self): GLPNEfficientSelfAttention(
#                 (query): Linear(in_features=128, out_features=128, bias=True)
#                 (key): Linear(in_features=128, out_features=128, bias=True)
#                 (value): Linear(in_features=128, out_features=128, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (sr): Conv2d(128, 128, kernel_size=(4, 4), stride=(4, 4))
#                 (layer_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#               )
#               (output): GLPNSelfOutput(
#                 (dense): Linear(in_features=128, out_features=128, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (drop_path): GLPNDropPath()
#             (layer_norm_2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#             (mlp): GLPNMixFFN(
#               (dense1): Linear(in_features=128, out_features=512, bias=True)
#               (dwconv): GLPNDWConv(
#                 (dwconv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#               )
#               (intermediate_act_fn): GELUActivation()
#               (dense2): Linear(in_features=512, out_features=128, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (4): GLPNLayer(
#             (layer_norm_1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#             (attention): GLPNAttention(
#               (self): GLPNEfficientSelfAttention(
#                 (query): Linear(in_features=128, out_features=128, bias=True)
#                 (key): Linear(in_features=128, out_features=128, bias=True)
#                 (value): Linear(in_features=128, out_features=128, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (sr): Conv2d(128, 128, kernel_size=(4, 4), stride=(4, 4))
#                 (layer_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#               )
#               (output): GLPNSelfOutput(
#                 (dense): Linear(in_features=128, out_features=128, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (drop_path): GLPNDropPath()
#             (layer_norm_2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#             (mlp): GLPNMixFFN(
#               (dense1): Linear(in_features=128, out_features=512, bias=True)
#               (dwconv): GLPNDWConv(
#                 (dwconv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#               )
#               (intermediate_act_fn): GELUActivation()
#               (dense2): Linear(in_features=512, out_features=128, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (5): GLPNLayer(
#             (layer_norm_1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#             (attention): GLPNAttention(
#               (self): GLPNEfficientSelfAttention(
#                 (query): Linear(in_features=128, out_features=128, bias=True)
#                 (key): Linear(in_features=128, out_features=128, bias=True)
#                 (value): Linear(in_features=128, out_features=128, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (sr): Conv2d(128, 128, kernel_size=(4, 4), stride=(4, 4))
#                 (layer_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#               )
#               (output): GLPNSelfOutput(
#                 (dense): Linear(in_features=128, out_features=128, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (drop_path): GLPNDropPath()
#             (layer_norm_2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#             (mlp): GLPNMixFFN(
#               (dense1): Linear(in_features=128, out_features=512, bias=True)
#               (dwconv): GLPNDWConv(
#                 (dwconv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#               )
#               (intermediate_act_fn): GELUActivation()
#               (dense2): Linear(in_features=512, out_features=128, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (6): GLPNLayer(
#             (layer_norm_1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#             (attention): GLPNAttention(
#               (self): GLPNEfficientSelfAttention(
#                 (query): Linear(in_features=128, out_features=128, bias=True)
#                 (key): Linear(in_features=128, out_features=128, bias=True)
#                 (value): Linear(in_features=128, out_features=128, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (sr): Conv2d(128, 128, kernel_size=(4, 4), stride=(4, 4))
#                 (layer_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#               )
#               (output): GLPNSelfOutput(
#                 (dense): Linear(in_features=128, out_features=128, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (drop_path): GLPNDropPath()
#             (layer_norm_2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#             (mlp): GLPNMixFFN(
#               (dense1): Linear(in_features=128, out_features=512, bias=True)
#               (dwconv): GLPNDWConv(
#                 (dwconv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#               )
#               (intermediate_act_fn): GELUActivation()
#               (dense2): Linear(in_features=512, out_features=128, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (7): GLPNLayer(
#             (layer_norm_1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#             (attention): GLPNAttention(
#               (self): GLPNEfficientSelfAttention(
#                 (query): Linear(in_features=128, out_features=128, bias=True)
#                 (key): Linear(in_features=128, out_features=128, bias=True)
#                 (value): Linear(in_features=128, out_features=128, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (sr): Conv2d(128, 128, kernel_size=(4, 4), stride=(4, 4))
#                 (layer_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#               )
#               (output): GLPNSelfOutput(
#                 (dense): Linear(in_features=128, out_features=128, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (drop_path): GLPNDropPath()
#             (layer_norm_2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#             (mlp): GLPNMixFFN(
#               (dense1): Linear(in_features=128, out_features=512, bias=True)
#               (dwconv): GLPNDWConv(
#                 (dwconv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#               )
#               (intermediate_act_fn): GELUActivation()
#               (dense2): Linear(in_features=512, out_features=128, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#         )
#         (2): ModuleList(
#           (0): GLPNLayer(
#             (layer_norm_1): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#             (attention): GLPNAttention(
#               (self): GLPNEfficientSelfAttention(
#                 (query): Linear(in_features=320, out_features=320, bias=True)
#                 (key): Linear(in_features=320, out_features=320, bias=True)
#                 (value): Linear(in_features=320, out_features=320, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (sr): Conv2d(320, 320, kernel_size=(2, 2), stride=(2, 2))
#                 (layer_norm): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#               )
#               (output): GLPNSelfOutput(
#                 (dense): Linear(in_features=320, out_features=320, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (drop_path): GLPNDropPath()
#             (layer_norm_2): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#             (mlp): GLPNMixFFN(
#               (dense1): Linear(in_features=320, out_features=1280, bias=True)
#               (dwconv): GLPNDWConv(
#                 (dwconv): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1280)
#               )
#               (intermediate_act_fn): GELUActivation()
#               (dense2): Linear(in_features=1280, out_features=320, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (1): GLPNLayer(
#             (layer_norm_1): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#             (attention): GLPNAttention(
#               (self): GLPNEfficientSelfAttention(
#                 (query): Linear(in_features=320, out_features=320, bias=True)
#                 (key): Linear(in_features=320, out_features=320, bias=True)
#                 (value): Linear(in_features=320, out_features=320, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (sr): Conv2d(320, 320, kernel_size=(2, 2), stride=(2, 2))
#                 (layer_norm): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#               )
#               (output): GLPNSelfOutput(
#                 (dense): Linear(in_features=320, out_features=320, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (drop_path): GLPNDropPath()
#             (layer_norm_2): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#             (mlp): GLPNMixFFN(
#               (dense1): Linear(in_features=320, out_features=1280, bias=True)
#               (dwconv): GLPNDWConv(
#                 (dwconv): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1280)
#               )
#               (intermediate_act_fn): GELUActivation()
#               (dense2): Linear(in_features=1280, out_features=320, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (2): GLPNLayer(
#             (layer_norm_1): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#             (attention): GLPNAttention(
#               (self): GLPNEfficientSelfAttention(
#                 (query): Linear(in_features=320, out_features=320, bias=True)
#                 (key): Linear(in_features=320, out_features=320, bias=True)
#                 (value): Linear(in_features=320, out_features=320, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (sr): Conv2d(320, 320, kernel_size=(2, 2), stride=(2, 2))
#                 (layer_norm): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#               )
#               (output): GLPNSelfOutput(
#                 (dense): Linear(in_features=320, out_features=320, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (drop_path): GLPNDropPath()
#             (layer_norm_2): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#             (mlp): GLPNMixFFN(
#               (dense1): Linear(in_features=320, out_features=1280, bias=True)
#               (dwconv): GLPNDWConv(
#                 (dwconv): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1280)
#               )
#               (intermediate_act_fn): GELUActivation()
#               (dense2): Linear(in_features=1280, out_features=320, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (3): GLPNLayer(
#             (layer_norm_1): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#             (attention): GLPNAttention(
#               (self): GLPNEfficientSelfAttention(
#                 (query): Linear(in_features=320, out_features=320, bias=True)
#                 (key): Linear(in_features=320, out_features=320, bias=True)
#                 (value): Linear(in_features=320, out_features=320, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (sr): Conv2d(320, 320, kernel_size=(2, 2), stride=(2, 2))
#                 (layer_norm): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#               )
#               (output): GLPNSelfOutput(
#                 (dense): Linear(in_features=320, out_features=320, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (drop_path): GLPNDropPath()
#             (layer_norm_2): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#             (mlp): GLPNMixFFN(
#               (dense1): Linear(in_features=320, out_features=1280, bias=True)
#               (dwconv): GLPNDWConv(
#                 (dwconv): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1280)
#               )
#               (intermediate_act_fn): GELUActivation()
#               (dense2): Linear(in_features=1280, out_features=320, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (4): GLPNLayer(
#             (layer_norm_1): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#             (attention): GLPNAttention(
#               (self): GLPNEfficientSelfAttention(
#                 (query): Linear(in_features=320, out_features=320, bias=True)
#                 (key): Linear(in_features=320, out_features=320, bias=True)
#                 (value): Linear(in_features=320, out_features=320, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (sr): Conv2d(320, 320, kernel_size=(2, 2), stride=(2, 2))
#                 (layer_norm): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#               )
#               (output): GLPNSelfOutput(
#                 (dense): Linear(in_features=320, out_features=320, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (drop_path): GLPNDropPath()
#             (layer_norm_2): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#             (mlp): GLPNMixFFN(
#               (dense1): Linear(in_features=320, out_features=1280, bias=True)
#               (dwconv): GLPNDWConv(
#                 (dwconv): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1280)
#               )
#               (intermediate_act_fn): GELUActivation()
#               (dense2): Linear(in_features=1280, out_features=320, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (5): GLPNLayer(
#             (layer_norm_1): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#             (attention): GLPNAttention(
#               (self): GLPNEfficientSelfAttention(
#                 (query): Linear(in_features=320, out_features=320, bias=True)
#                 (key): Linear(in_features=320, out_features=320, bias=True)
#                 (value): Linear(in_features=320, out_features=320, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (sr): Conv2d(320, 320, kernel_size=(2, 2), stride=(2, 2))
#                 (layer_norm): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#               )
#               (output): GLPNSelfOutput(
#                 (dense): Linear(in_features=320, out_features=320, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (drop_path): GLPNDropPath()
#             (layer_norm_2): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#             (mlp): GLPNMixFFN(
#               (dense1): Linear(in_features=320, out_features=1280, bias=True)
#               (dwconv): GLPNDWConv(
#                 (dwconv): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1280)
#               )
#               (intermediate_act_fn): GELUActivation()
#               (dense2): Linear(in_features=1280, out_features=320, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (6): GLPNLayer(
#             (layer_norm_1): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#             (attention): GLPNAttention(
#               (self): GLPNEfficientSelfAttention(
#                 (query): Linear(in_features=320, out_features=320, bias=True)
#                 (key): Linear(in_features=320, out_features=320, bias=True)
#                 (value): Linear(in_features=320, out_features=320, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (sr): Conv2d(320, 320, kernel_size=(2, 2), stride=(2, 2))
#                 (layer_norm): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#               )
#               (output): GLPNSelfOutput(
#                 (dense): Linear(in_features=320, out_features=320, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (drop_path): GLPNDropPath()
#             (layer_norm_2): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#             (mlp): GLPNMixFFN(
#               (dense1): Linear(in_features=320, out_features=1280, bias=True)
#               (dwconv): GLPNDWConv(
#                 (dwconv): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1280)
#               )
#               (intermediate_act_fn): GELUActivation()
#               (dense2): Linear(in_features=1280, out_features=320, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (7): GLPNLayer(
#             (layer_norm_1): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#             (attention): GLPNAttention(
#               (self): GLPNEfficientSelfAttention(
#                 (query): Linear(in_features=320, out_features=320, bias=True)
#                 (key): Linear(in_features=320, out_features=320, bias=True)
#                 (value): Linear(in_features=320, out_features=320, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (sr): Conv2d(320, 320, kernel_size=(2, 2), stride=(2, 2))
#                 (layer_norm): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#               )
#               (output): GLPNSelfOutput(
#                 (dense): Linear(in_features=320, out_features=320, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (drop_path): GLPNDropPath()
#             (layer_norm_2): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#             (mlp): GLPNMixFFN(
#               (dense1): Linear(in_features=320, out_features=1280, bias=True)
#               (dwconv): GLPNDWConv(
#                 (dwconv): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1280)
#               )
#               (intermediate_act_fn): GELUActivation()
#               (dense2): Linear(in_features=1280, out_features=320, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (8): GLPNLayer(
#             (layer_norm_1): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#             (attention): GLPNAttention(
#               (self): GLPNEfficientSelfAttention(
#                 (query): Linear(in_features=320, out_features=320, bias=True)
#                 (key): Linear(in_features=320, out_features=320, bias=True)
#                 (value): Linear(in_features=320, out_features=320, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (sr): Conv2d(320, 320, kernel_size=(2, 2), stride=(2, 2))
#                 (layer_norm): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#               )
#               (output): GLPNSelfOutput(
#                 (dense): Linear(in_features=320, out_features=320, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (drop_path): GLPNDropPath()
#             (layer_norm_2): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#             (mlp): GLPNMixFFN(
#               (dense1): Linear(in_features=320, out_features=1280, bias=True)
#               (dwconv): GLPNDWConv(
#                 (dwconv): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1280)
#               )
#               (intermediate_act_fn): GELUActivation()
#               (dense2): Linear(in_features=1280, out_features=320, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (9): GLPNLayer(
#             (layer_norm_1): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#             (attention): GLPNAttention(
#               (self): GLPNEfficientSelfAttention(
#                 (query): Linear(in_features=320, out_features=320, bias=True)
#                 (key): Linear(in_features=320, out_features=320, bias=True)
#                 (value): Linear(in_features=320, out_features=320, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (sr): Conv2d(320, 320, kernel_size=(2, 2), stride=(2, 2))
#                 (layer_norm): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#               )
#               (output): GLPNSelfOutput(
#                 (dense): Linear(in_features=320, out_features=320, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (drop_path): GLPNDropPath()
#             (layer_norm_2): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#             (mlp): GLPNMixFFN(
#               (dense1): Linear(in_features=320, out_features=1280, bias=True)
#               (dwconv): GLPNDWConv(
#                 (dwconv): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1280)
#               )
#               (intermediate_act_fn): GELUActivation()
#               (dense2): Linear(in_features=1280, out_features=320, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (10): GLPNLayer(
#             (layer_norm_1): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#             (attention): GLPNAttention(
#               (self): GLPNEfficientSelfAttention(
#                 (query): Linear(in_features=320, out_features=320, bias=True)
#                 (key): Linear(in_features=320, out_features=320, bias=True)
#                 (value): Linear(in_features=320, out_features=320, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (sr): Conv2d(320, 320, kernel_size=(2, 2), stride=(2, 2))
#                 (layer_norm): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#               )
#               (output): GLPNSelfOutput(
#                 (dense): Linear(in_features=320, out_features=320, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (drop_path): GLPNDropPath()
#             (layer_norm_2): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#             (mlp): GLPNMixFFN(
#               (dense1): Linear(in_features=320, out_features=1280, bias=True)
#               (dwconv): GLPNDWConv(
#                 (dwconv): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1280)
#               )
#               (intermediate_act_fn): GELUActivation()
#               (dense2): Linear(in_features=1280, out_features=320, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (11): GLPNLayer(
#             (layer_norm_1): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#             (attention): GLPNAttention(
#               (self): GLPNEfficientSelfAttention(
#                 (query): Linear(in_features=320, out_features=320, bias=True)
#                 (key): Linear(in_features=320, out_features=320, bias=True)
#                 (value): Linear(in_features=320, out_features=320, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (sr): Conv2d(320, 320, kernel_size=(2, 2), stride=(2, 2))
#                 (layer_norm): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#               )
#               (output): GLPNSelfOutput(
#                 (dense): Linear(in_features=320, out_features=320, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (drop_path): GLPNDropPath()
#             (layer_norm_2): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#             (mlp): GLPNMixFFN(
#               (dense1): Linear(in_features=320, out_features=1280, bias=True)
#               (dwconv): GLPNDWConv(
#                 (dwconv): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1280)
#               )
#               (intermediate_act_fn): GELUActivation()
#               (dense2): Linear(in_features=1280, out_features=320, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (12): GLPNLayer(
#             (layer_norm_1): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#             (attention): GLPNAttention(
#               (self): GLPNEfficientSelfAttention(
#                 (query): Linear(in_features=320, out_features=320, bias=True)
#                 (key): Linear(in_features=320, out_features=320, bias=True)
#                 (value): Linear(in_features=320, out_features=320, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (sr): Conv2d(320, 320, kernel_size=(2, 2), stride=(2, 2))
#                 (layer_norm): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#               )
#               (output): GLPNSelfOutput(
#                 (dense): Linear(in_features=320, out_features=320, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (drop_path): GLPNDropPath()
#             (layer_norm_2): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#             (mlp): GLPNMixFFN(
#               (dense1): Linear(in_features=320, out_features=1280, bias=True)
#               (dwconv): GLPNDWConv(
#                 (dwconv): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1280)
#               )
#               (intermediate_act_fn): GELUActivation()
#               (dense2): Linear(in_features=1280, out_features=320, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (13): GLPNLayer(
#             (layer_norm_1): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#             (attention): GLPNAttention(
#               (self): GLPNEfficientSelfAttention(
#                 (query): Linear(in_features=320, out_features=320, bias=True)
#                 (key): Linear(in_features=320, out_features=320, bias=True)
#                 (value): Linear(in_features=320, out_features=320, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (sr): Conv2d(320, 320, kernel_size=(2, 2), stride=(2, 2))
#                 (layer_norm): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#               )
#               (output): GLPNSelfOutput(
#                 (dense): Linear(in_features=320, out_features=320, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (drop_path): GLPNDropPath()
#             (layer_norm_2): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#             (mlp): GLPNMixFFN(
#               (dense1): Linear(in_features=320, out_features=1280, bias=True)
#               (dwconv): GLPNDWConv(
#                 (dwconv): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1280)
#               )
#               (intermediate_act_fn): GELUActivation()
#               (dense2): Linear(in_features=1280, out_features=320, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (14): GLPNLayer(
#             (layer_norm_1): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#             (attention): GLPNAttention(
#               (self): GLPNEfficientSelfAttention(
#                 (query): Linear(in_features=320, out_features=320, bias=True)
#                 (key): Linear(in_features=320, out_features=320, bias=True)
#                 (value): Linear(in_features=320, out_features=320, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (sr): Conv2d(320, 320, kernel_size=(2, 2), stride=(2, 2))
#                 (layer_norm): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#               )
#               (output): GLPNSelfOutput(
#                 (dense): Linear(in_features=320, out_features=320, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (drop_path): GLPNDropPath()
#             (layer_norm_2): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#             (mlp): GLPNMixFFN(
#               (dense1): Linear(in_features=320, out_features=1280, bias=True)
#               (dwconv): GLPNDWConv(
#                 (dwconv): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1280)
#               )
#               (intermediate_act_fn): GELUActivation()
#               (dense2): Linear(in_features=1280, out_features=320, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (15): GLPNLayer(
#             (layer_norm_1): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#             (attention): GLPNAttention(
#               (self): GLPNEfficientSelfAttention(
#                 (query): Linear(in_features=320, out_features=320, bias=True)
#                 (key): Linear(in_features=320, out_features=320, bias=True)
#                 (value): Linear(in_features=320, out_features=320, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (sr): Conv2d(320, 320, kernel_size=(2, 2), stride=(2, 2))
#                 (layer_norm): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#               )
#               (output): GLPNSelfOutput(
#                 (dense): Linear(in_features=320, out_features=320, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (drop_path): GLPNDropPath()
#             (layer_norm_2): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#             (mlp): GLPNMixFFN(
#               (dense1): Linear(in_features=320, out_features=1280, bias=True)
#               (dwconv): GLPNDWConv(
#                 (dwconv): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1280)
#               )
#               (intermediate_act_fn): GELUActivation()
#               (dense2): Linear(in_features=1280, out_features=320, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (16): GLPNLayer(
#             (layer_norm_1): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#             (attention): GLPNAttention(
#               (self): GLPNEfficientSelfAttention(
#                 (query): Linear(in_features=320, out_features=320, bias=True)
#                 (key): Linear(in_features=320, out_features=320, bias=True)
#                 (value): Linear(in_features=320, out_features=320, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (sr): Conv2d(320, 320, kernel_size=(2, 2), stride=(2, 2))
#                 (layer_norm): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#               )
#               (output): GLPNSelfOutput(
#                 (dense): Linear(in_features=320, out_features=320, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (drop_path): GLPNDropPath()
#             (layer_norm_2): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#             (mlp): GLPNMixFFN(
#               (dense1): Linear(in_features=320, out_features=1280, bias=True)
#               (dwconv): GLPNDWConv(
#                 (dwconv): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1280)
#               )
#               (intermediate_act_fn): GELUActivation()
#               (dense2): Linear(in_features=1280, out_features=320, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (17): GLPNLayer(
#             (layer_norm_1): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#             (attention): GLPNAttention(
#               (self): GLPNEfficientSelfAttention(
#                 (query): Linear(in_features=320, out_features=320, bias=True)
#                 (key): Linear(in_features=320, out_features=320, bias=True)
#                 (value): Linear(in_features=320, out_features=320, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (sr): Conv2d(320, 320, kernel_size=(2, 2), stride=(2, 2))
#                 (layer_norm): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#               )
#               (output): GLPNSelfOutput(
#                 (dense): Linear(in_features=320, out_features=320, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (drop_path): GLPNDropPath()
#             (layer_norm_2): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#             (mlp): GLPNMixFFN(
#               (dense1): Linear(in_features=320, out_features=1280, bias=True)
#               (dwconv): GLPNDWConv(
#                 (dwconv): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1280)
#               )
#               (intermediate_act_fn): GELUActivation()
#               (dense2): Linear(in_features=1280, out_features=320, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (18): GLPNLayer(
#             (layer_norm_1): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#             (attention): GLPNAttention(
#               (self): GLPNEfficientSelfAttention(
#                 (query): Linear(in_features=320, out_features=320, bias=True)
#                 (key): Linear(in_features=320, out_features=320, bias=True)
#                 (value): Linear(in_features=320, out_features=320, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (sr): Conv2d(320, 320, kernel_size=(2, 2), stride=(2, 2))
#                 (layer_norm): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#               )
#               (output): GLPNSelfOutput(
#                 (dense): Linear(in_features=320, out_features=320, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (drop_path): GLPNDropPath()
#             (layer_norm_2): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#             (mlp): GLPNMixFFN(
#               (dense1): Linear(in_features=320, out_features=1280, bias=True)
#               (dwconv): GLPNDWConv(
#                 (dwconv): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1280)
#               )
#               (intermediate_act_fn): GELUActivation()
#               (dense2): Linear(in_features=1280, out_features=320, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (19): GLPNLayer(
#             (layer_norm_1): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#             (attention): GLPNAttention(
#               (self): GLPNEfficientSelfAttention(
#                 (query): Linear(in_features=320, out_features=320, bias=True)
#                 (key): Linear(in_features=320, out_features=320, bias=True)
#                 (value): Linear(in_features=320, out_features=320, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (sr): Conv2d(320, 320, kernel_size=(2, 2), stride=(2, 2))
#                 (layer_norm): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#               )
#               (output): GLPNSelfOutput(
#                 (dense): Linear(in_features=320, out_features=320, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (drop_path): GLPNDropPath()
#             (layer_norm_2): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#             (mlp): GLPNMixFFN(
#               (dense1): Linear(in_features=320, out_features=1280, bias=True)
#               (dwconv): GLPNDWConv(
#                 (dwconv): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1280)
#               )
#               (intermediate_act_fn): GELUActivation()
#               (dense2): Linear(in_features=1280, out_features=320, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (20): GLPNLayer(
#             (layer_norm_1): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#             (attention): GLPNAttention(
#               (self): GLPNEfficientSelfAttention(
#                 (query): Linear(in_features=320, out_features=320, bias=True)
#                 (key): Linear(in_features=320, out_features=320, bias=True)
#                 (value): Linear(in_features=320, out_features=320, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (sr): Conv2d(320, 320, kernel_size=(2, 2), stride=(2, 2))
#                 (layer_norm): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#               )
#               (output): GLPNSelfOutput(
#                 (dense): Linear(in_features=320, out_features=320, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (drop_path): GLPNDropPath()
#             (layer_norm_2): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#             (mlp): GLPNMixFFN(
#               (dense1): Linear(in_features=320, out_features=1280, bias=True)
#               (dwconv): GLPNDWConv(
#                 (dwconv): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1280)
#               )
#               (intermediate_act_fn): GELUActivation()
#               (dense2): Linear(in_features=1280, out_features=320, bias=True)
# ...
#                 (value): Linear(in_features=320, out_features=320, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (sr): Conv2d(320, 320, kernel_size=(2, 2), stride=(2, 2))
#                 (layer_norm): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#               )
#               (output): GLPNSelfOutput(
#                 (dense): Linear(in_features=320, out_features=320, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (drop_path): GLPNDropPath()
#             (layer_norm_2): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#             (mlp): GLPNMixFFN(
#               (dense1): Linear(in_features=320, out_features=1280, bias=True)
#               (dwconv): GLPNDWConv(
#                 (dwconv): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1280)
#               )
#               (intermediate_act_fn): GELUActivation()
#               (dense2): Linear(in_features=1280, out_features=320, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (22): GLPNLayer(
#             (layer_norm_1): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#             (attention): GLPNAttention(
#               (self): GLPNEfficientSelfAttention(
#                 (query): Linear(in_features=320, out_features=320, bias=True)
#                 (key): Linear(in_features=320, out_features=320, bias=True)
#                 (value): Linear(in_features=320, out_features=320, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (sr): Conv2d(320, 320, kernel_size=(2, 2), stride=(2, 2))
#                 (layer_norm): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#               )
#               (output): GLPNSelfOutput(
#                 (dense): Linear(in_features=320, out_features=320, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (drop_path): GLPNDropPath()
#             (layer_norm_2): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#             (mlp): GLPNMixFFN(
#               (dense1): Linear(in_features=320, out_features=1280, bias=True)
#               (dwconv): GLPNDWConv(
#                 (dwconv): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1280)
#               )
#               (intermediate_act_fn): GELUActivation()
#               (dense2): Linear(in_features=1280, out_features=320, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (23): GLPNLayer(
#             (layer_norm_1): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#             (attention): GLPNAttention(
#               (self): GLPNEfficientSelfAttention(
#                 (query): Linear(in_features=320, out_features=320, bias=True)
#                 (key): Linear(in_features=320, out_features=320, bias=True)
#                 (value): Linear(in_features=320, out_features=320, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (sr): Conv2d(320, 320, kernel_size=(2, 2), stride=(2, 2))
#                 (layer_norm): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#               )
#               (output): GLPNSelfOutput(
#                 (dense): Linear(in_features=320, out_features=320, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (drop_path): GLPNDropPath()
#             (layer_norm_2): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#             (mlp): GLPNMixFFN(
#               (dense1): Linear(in_features=320, out_features=1280, bias=True)
#               (dwconv): GLPNDWConv(
#                 (dwconv): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1280)
#               )
#               (intermediate_act_fn): GELUActivation()
#               (dense2): Linear(in_features=1280, out_features=320, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (24): GLPNLayer(
#             (layer_norm_1): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#             (attention): GLPNAttention(
#               (self): GLPNEfficientSelfAttention(
#                 (query): Linear(in_features=320, out_features=320, bias=True)
#                 (key): Linear(in_features=320, out_features=320, bias=True)
#                 (value): Linear(in_features=320, out_features=320, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (sr): Conv2d(320, 320, kernel_size=(2, 2), stride=(2, 2))
#                 (layer_norm): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#               )
#               (output): GLPNSelfOutput(
#                 (dense): Linear(in_features=320, out_features=320, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (drop_path): GLPNDropPath()
#             (layer_norm_2): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#             (mlp): GLPNMixFFN(
#               (dense1): Linear(in_features=320, out_features=1280, bias=True)
#               (dwconv): GLPNDWConv(
#                 (dwconv): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1280)
#               )
#               (intermediate_act_fn): GELUActivation()
#               (dense2): Linear(in_features=1280, out_features=320, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (25): GLPNLayer(
#             (layer_norm_1): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#             (attention): GLPNAttention(
#               (self): GLPNEfficientSelfAttention(
#                 (query): Linear(in_features=320, out_features=320, bias=True)
#                 (key): Linear(in_features=320, out_features=320, bias=True)
#                 (value): Linear(in_features=320, out_features=320, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (sr): Conv2d(320, 320, kernel_size=(2, 2), stride=(2, 2))
#                 (layer_norm): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#               )
#               (output): GLPNSelfOutput(
#                 (dense): Linear(in_features=320, out_features=320, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (drop_path): GLPNDropPath()
#             (layer_norm_2): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#             (mlp): GLPNMixFFN(
#               (dense1): Linear(in_features=320, out_features=1280, bias=True)
#               (dwconv): GLPNDWConv(
#                 (dwconv): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1280)
#               )
#               (intermediate_act_fn): GELUActivation()
#               (dense2): Linear(in_features=1280, out_features=320, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (26): GLPNLayer(
#             (layer_norm_1): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#             (attention): GLPNAttention(
#               (self): GLPNEfficientSelfAttention(
#                 (query): Linear(in_features=320, out_features=320, bias=True)
#                 (key): Linear(in_features=320, out_features=320, bias=True)
#                 (value): Linear(in_features=320, out_features=320, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (sr): Conv2d(320, 320, kernel_size=(2, 2), stride=(2, 2))
#                 (layer_norm): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#               )
#               (output): GLPNSelfOutput(
#                 (dense): Linear(in_features=320, out_features=320, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (drop_path): GLPNDropPath()
#             (layer_norm_2): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#             (mlp): GLPNMixFFN(
#               (dense1): Linear(in_features=320, out_features=1280, bias=True)
#               (dwconv): GLPNDWConv(
#                 (dwconv): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1280)
#               )
#               (intermediate_act_fn): GELUActivation()
#               (dense2): Linear(in_features=1280, out_features=320, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#         )
#         (3): ModuleList(
#           (0): GLPNLayer(
#             (layer_norm_1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (attention): GLPNAttention(
#               (self): GLPNEfficientSelfAttention(
#                 (query): Linear(in_features=512, out_features=512, bias=True)
#                 (key): Linear(in_features=512, out_features=512, bias=True)
#                 (value): Linear(in_features=512, out_features=512, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#               (output): GLPNSelfOutput(
#                 (dense): Linear(in_features=512, out_features=512, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (drop_path): GLPNDropPath()
#             (layer_norm_2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (mlp): GLPNMixFFN(
#               (dense1): Linear(in_features=512, out_features=2048, bias=True)
#               (dwconv): GLPNDWConv(
#                 (dwconv): Conv2d(2048, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2048)
#               )
#               (intermediate_act_fn): GELUActivation()
#               (dense2): Linear(in_features=2048, out_features=512, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (1): GLPNLayer(
#             (layer_norm_1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (attention): GLPNAttention(
#               (self): GLPNEfficientSelfAttention(
#                 (query): Linear(in_features=512, out_features=512, bias=True)
#                 (key): Linear(in_features=512, out_features=512, bias=True)
#                 (value): Linear(in_features=512, out_features=512, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#               (output): GLPNSelfOutput(
#                 (dense): Linear(in_features=512, out_features=512, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (drop_path): GLPNDropPath()
#             (layer_norm_2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (mlp): GLPNMixFFN(
#               (dense1): Linear(in_features=512, out_features=2048, bias=True)
#               (dwconv): GLPNDWConv(
#                 (dwconv): Conv2d(2048, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2048)
#               )
#               (intermediate_act_fn): GELUActivation()
#               (dense2): Linear(in_features=2048, out_features=512, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (2): GLPNLayer(
#             (layer_norm_1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (attention): GLPNAttention(
#               (self): GLPNEfficientSelfAttention(
#                 (query): Linear(in_features=512, out_features=512, bias=True)
#                 (key): Linear(in_features=512, out_features=512, bias=True)
#                 (value): Linear(in_features=512, out_features=512, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#               (output): GLPNSelfOutput(
#                 (dense): Linear(in_features=512, out_features=512, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (drop_path): GLPNDropPath()
#             (layer_norm_2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (mlp): GLPNMixFFN(
#               (dense1): Linear(in_features=512, out_features=2048, bias=True)
#               (dwconv): GLPNDWConv(
#                 (dwconv): Conv2d(2048, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2048)
#               )
#               (intermediate_act_fn): GELUActivation()
#               (dense2): Linear(in_features=2048, out_features=512, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#         )
#       )
#       (layer_norm): ModuleList(
#         (0): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         (1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (2): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#         (3): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#   )
#   (decoder): GLPNDecoder(
#     (stages): ModuleList(
#       (0): GLPNDecoderStage(
#         (convolution): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1))
#         (fusion): None
#         (upsample): Upsample(scale_factor=2.0, mode=bilinear)
#       )
#       (1): GLPNDecoderStage(
#         (convolution): Conv2d(320, 64, kernel_size=(1, 1), stride=(1, 1))
#         (fusion): GLPNSelectiveFeatureFusion(
#           (convolutional_layer1): Sequential(
#             (0): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU()
#           )
#           (convolutional_layer2): Sequential(
#             (0): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU()
#           )
#           (convolutional_layer3): Conv2d(32, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#         (upsample): Upsample(scale_factor=2.0, mode=bilinear)
#       )
#       (2): GLPNDecoderStage(
#         (convolution): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#         (fusion): GLPNSelectiveFeatureFusion(
#           (convolutional_layer1): Sequential(
#             (0): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU()
#           )
#           (convolutional_layer2): Sequential(
#             (0): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU()
#           )
#           (convolutional_layer3): Conv2d(32, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#         (upsample): Upsample(scale_factor=2.0, mode=bilinear)
#       )
#       (3): GLPNDecoderStage(
#         (convolution): Identity()
#         (fusion): GLPNSelectiveFeatureFusion(
#           (convolutional_layer1): Sequential(
#             (0): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU()
#           )
#           (convolutional_layer2): Sequential(
#             (0): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU()
#           )
#           (convolutional_layer3): Conv2d(32, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#         (upsample): Upsample(scale_factor=2.0, mode=bilinear)
#       )
#     )
#     (final_upsample): Upsample(scale_factor=2.0, mode=bilinear)
#   )
#   (head): GLPNDepthEstimationHead(
#     (head): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU()
#       (2): Conv2d(64, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#   )
# )

# %%
train_image_list = os.listdir('./data/image/train') # 7481

# %%
len(train_image_list)
# Out:
# 7481

# %%
depth_info = pd.DataFrame(columns={'depth_min','depth_mean','depth_x','depth_y'})

k=50
filename = train_image_list[k]

img = Image.open(os.path.join('./data/image/train/',filename))
img_shape = cv2.imread(os.path.join('./data/image/train/',filename)).shape

df_choose = glp_kitti_preprocessing_data[glp_kitti_preprocessing_data['filename']==filename]
df_choose
# Out:
#        filename class       xmin       ymin        xmax       ymax  angle  \
# 160  000050.png   car  680.52650  174.20996   801.96820  255.57779  -1.75
# 161  000050.png   car  262.65292  184.14255   473.83612  306.70782  -1.31
# 162  000050.png   car  928.40730  218.18613  1241.64900  370.26282  -2.37
# 163  000050.png   car  638.23114  167.94492   681.41710  203.62890  -1.58
#
#       zloc weather
# 160  14.75   clone
# 161   9.79   clone
# 162   2.39   clone
# 163  31.72   clone

# %%
with torch.no_grad(): # Depth map
    pixel_values = feature_extractor(img, return_tensors="pt").pixel_values
    outputs = model(pixel_values) 
    predicted_depth = outputs.predicted_depth
    
    # interpolate to original size
    prediction = torch.nn.functional.interpolate(
                        predicted_depth.unsqueeze(1),
                        size=img_shape[:2],
                        mode="bicubic",
                        align_corners=False,
                 )
    prediction = prediction.squeeze().cpu().numpy() # shape => (375, 1242)

# %%
coordinates_array = df_choose[['xmin','ymin','xmax','ymax']].values
coordinates_array
# Out:
# array([[ 680.5265 ,  174.20996,  801.9682 ,  255.57779],
#        [ 262.65292,  184.14255,  473.83612,  306.70782],
#        [ 928.4073 ,  218.18613, 1241.649  ,  370.26282],
#        [ 638.23114,  167.94492,  681.4171 ,  203.6289 ]])

# %%
depth_mean = []
depth_min = []
depth_x = []
depth_y = []
for (xmin, ymin, xmax, ymax) in coordinates_array:
    depth_mean_info = prediction[int(ymin):int(ymax),int(xmin):int(xmax)].mean()
    depth_min_info = prediction[int(ymin):int(ymax),int(xmin):int(xmax)].min()
    
    xy = np.where(prediction==depth_min_info)
    print(xy)
    
    depth_x.append(xy[1][0])
    depth_y.append(xy[0][0])
    depth_mean.append(depth_mean_info)
    depth_min.append(depth_min_info)
# Out:
# (array([199], dtype=int64), array([791], dtype=int64))
# (array([224], dtype=int64), array([285], dtype=int64))
# (array([367], dtype=int64), array([1229], dtype=int64))
# (array([192], dtype=int64), array([680], dtype=int64))

# %%
depth_mean
# Out:
# [2.0755568, 1.2589086, 0.6425098, 4.7720723]

# %%
depth_min
# Out:
# [1.6308248, 0.9789565, 0.3243949, 3.7501798]

# %%
depth_info['depth_mean'] = depth_mean

# %%
depth_info['depth_min'] = depth_min

# %%
depth_info['depth_x'] = depth_x

# %%
depth_info['depth_y'] = depth_y

# %%
depth_info
# Out:
#   depth_y  depth_min depth_x  depth_mean
# 0   [199]   1.630825   [791]    2.075557
# 1   [224]   0.978957   [285]    1.258909
# 2   [367]   0.324395  [1229]    0.642510
# 3   [192]   3.750180   [680]    4.772072
