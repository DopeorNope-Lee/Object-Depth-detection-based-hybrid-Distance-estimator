# %% [markdown]
# #Distance Estimator
# To estimate the real distance(unit: meter) of the object
#
# __Input__: Bounding box coordinates(xmin, ymin, xmax, ymax)
# __Output__: 3D location z of carmera coordinates(z_loc)

# %% [markdown]
# ## Load Module

# %%
from tqdm import tqdm
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time
import torch
import category_encoders as ce
from torch import nn
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader 
from sklearn.preprocessing import StandardScaler
from custom_datasets import CustomDataset
from sklearn.metrics import mean_squared_error
import math
from sklearn.preprocessing import MinMaxScaler,StandardScaler, LabelEncoder

# %%
os.makedirs('./weights', exist_ok=True)

# %% [markdown]
# ## Dataset

# %%
df_train = pd.read_csv('../datasets/iou1_train.csv')
df_valid = pd.read_csv('../datasets/iou1_valid.csv')
df_test = pd.read_csv('../datasets/iou1_test.csv')

# %%
# zloc 조건
#df_train = df_train[df_train['zloc']<90]
#df_valid = df_valid[df_valid['zloc']<90]
#df_test = df_test[df_test['zloc']<90]

# %%
df_train['class'].unique()
# Out:
# array(['car', 'train', 'person', 'Misc', 'truck', 'bicycle'], dtype=object)

# %%
# onehot encoding
class_dummy = pd.get_dummies(df_train['class'])
df_train = pd.concat([df_train, class_dummy], axis=1)

class_dummy = pd.get_dummies(df_valid['class'])
df_valid = pd.concat([df_valid, class_dummy], axis=1)

class_dummy = pd.get_dummies(df_test['class'])
df_test = pd.concat([df_test, class_dummy], axis=1)

# %%
# TrVd
#df_train = pd.concat([df_train, df_valid], axis=0)

# %%
le = LabelEncoder()
train_label = le.fit_transform(df_train['class'])
df_train['class_num'] = train_label

valid_label = le.fit_transform(df_valid['class'])
df_valid['class_num'] = valid_label

test_label = le.fit_transform(df_test['class'])
df_test['class_num'] = test_label

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21616 entries, 0 to 21615
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   filename         21616 non-null  object
#  1   class            21616 non-null  object
#  2   xmin             21616 non-null  float64
#  3   ymin             21616 non-null  float64
#  4   xmax             21616 non-null  float64
#  5   ymax             21616 non-null  float64
#  6   angle            21616 non-null  float64
#  7   zloc             21616 non-null  float64
#  8   weather          21616 non-null  object
#  9   iou              21616 non-null  float64
#  10  depth_y          21616 non-null  int64
#  11  depth_min        21616 non-null  float64
#  12  depth_mean       21616 non-null  float64
#  13  depth_x          21616 non-null  int64
#  14  depth_median     21616 non-null  float64
#  15  depth_max        21616 non-null  float64
#  16  depth_mean_trim  21616 non-null  float64
#  17  width            21616 non-null  float64
#  18  height           21616 non-null  float64
#  19  Misc             21616 non-null  uint8
#  20  bicycle          21616 non-null  uint8
#  21  car              21616 non-null  uint8
#  22  person           21616 non-null  uint8
#  23  train            21616 non-null  uint8
#  24  truck            21616 non-null  uint8
#  25  class_num        21616 non-null  int32
# dtypes: float64(14), int32(1), int64(2), object(3), uint8(6)
# memory usage: 3.3+ MB

# %%
variable = ['xmin','ymin','xmax','ymax','width', 'height', 'depth_mean_trim', 'depth_mean','depth_median','Misc', 'bicycle', 'car', 'person', 'train', 'truck']
val_length = len(variable)
batch_sz = 24
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# train
train_dataset = CustomDataset(df_train, variable, scaler=True, train=True, onehot=False)
train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_sz, shuffle=True)
# train_sclaer
scaler_train = train_dataset.scaler

# valid
valid_dataset = CustomDataset(df_valid, variable, True, train=scaler_train, onehot=False)
valid_dataloader = torch.utils.data.DataLoader(valid_dataset, batch_size=batch_sz, shuffle=True)

# test
test_dataset = CustomDataset(df_test, variable, True, train=scaler_train, onehot=False)
test_dataloader = torch.utils.data.DataLoader(test_dataset, batch_size=len(df_test), shuffle=False)

# %%
val_length # 13
# Out:
# 15

# %%
# look dataset
for idx, batch in enumerate(train_dataloader):
    if idx == 1:
        break
    print(batch[0])
    print(batch[0].shape)
    print(batch[1])
# Out:
# tensor([[-5.3258e-01,  3.8890e-01, -7.2444e-01, -8.2952e-01, -5.7294e-01,
#          -1.0102e+00,  1.1167e+00,  1.0208e+00,  1.1005e+00, -7.8384e-02,
#          -4.8150e-02,  4.2500e-01, -3.5745e-01, -8.3873e-02, -1.5777e-01],
#         [ 9.9051e-02, -2.6257e-01, -8.0690e-02, -5.9213e-01, -5.4328e-01,
#          -5.1341e-01,  1.3994e-01,  2.0135e-01,  1.3600e-01, -7.8384e-02,
#          -4.8150e-02,  4.2500e-01, -3.5745e-01, -8.3873e-02, -1.5777e-01],
#         [ 3.2261e-01, -8.1105e-01,  1.0627e-01, -9.3391e-01, -6.5613e-01,
#          -6.5713e-01,  6.0213e-01,  7.0989e-01,  5.6976e-01, -7.8384e-02,
#          -4.8150e-02,  4.2500e-01, -3.5745e-01, -8.3873e-02, -1.5777e-01],
#         [ 1.3264e-01,  1.5379e-01, -1.4150e-01, -9.2243e-01, -8.2842e-01,
#          -1.0162e+00,  1.4100e+00,  1.3485e+00,  1.4177e+00, -7.8384e-02,
#          -4.8150e-02,  4.2500e-01, -3.5745e-01, -8.3873e-02, -1.5777e-01],
#         [-4.8724e-01,  2.7508e-02, -4.0573e-01,  1.8846e-01,  2.5122e-01,
#           1.8496e-01, -6.9565e-01, -7.1205e-01, -6.9117e-01, -7.8384e-02,
#          -4.8150e-02,  4.2500e-01, -3.5745e-01, -8.3873e-02, -1.5777e-01],
#         [ 5.7832e-01, -4.3754e-02,  3.0890e-01, -9.8805e-01, -8.1904e-01,
#          -1.0083e+00,  2.5687e+00,  2.4643e+00,  2.5947e+00, -7.8384e-02,
#          -4.8150e-02,  4.2500e-01, -3.5745e-01, -8.3873e-02, -1.5777e-01],
#         [-2.1507e-01,  5.1819e-03, -1.6660e-01, -2.8000e-01,  1.4854e-01,
#          -2.9251e-01, -3.4794e-01, -2.4678e-01, -3.4596e-01, -7.8384e-02,
#          -4.8150e-02,  4.2500e-01, -3.5745e-01, -8.3873e-02, -1.5777e-01],
#         [-1.5812e-01, -1.8886e-01, -1.7090e-01, -6.1710e-01, -3.6812e-02,
#          -5.6766e-01,  1.6469e-01,  3.3237e-01,  1.5997e-01, -7.8384e-02,
#          -4.8150e-02,  4.2500e-01, -3.5745e-01, -8.3873e-02, -1.5777e-01],
#         [-1.0156e+00, -2.2374e-01, -1.1367e+00,  2.1805e+00, -3.5412e-01,
#           2.3484e+00, -1.2112e+00, -1.3070e+00, -1.2060e+00, -7.8384e-02,
#          -4.8150e-02, -2.3530e+00,  2.7976e+00, -8.3873e-02, -1.5777e-01],
#         [ 1.0763e+00,  2.2675e-01,  8.0798e-01, -8.4909e-01, -8.2119e-01,
#          -9.6818e-01,  2.4030e+00,  2.2706e+00,  2.4287e+00, -7.8384e-02,
#          -4.8150e-02,  4.2500e-01, -3.5745e-01, -8.3873e-02, -1.5777e-01],
#         [-1.3934e+00,  1.0080e+00, -6.6995e-01,  2.1069e+00,  2.1976e+00,
#           1.7984e+00, -1.1840e+00, -1.2275e+00, -1.1851e+00, -7.8384e-02,
#          -4.8150e-02,  4.2500e-01, -3.5745e-01, -8.3873e-02, -1.5777e-01],
#         [ 1.9925e+00, -1.0356e+00,  2.1900e+00, -8.1058e-01,  5.7381e-01,
#          -4.4282e-01, -1.1926e-01, -1.7029e-01, -1.1948e-01, -7.8384e-02,
#          -4.8150e-02,  4.2500e-01, -3.5745e-01, -8.3873e-02, -1.5777e-01],
#         [-4.0936e-01,  3.1866e-01, -4.7685e-01, -1.2089e-01, -1.9908e-01,
#          -2.4796e-01, -3.0479e-01, -3.4216e-01, -3.0070e-01, -7.8384e-02,
#          -4.8150e-02,  4.2500e-01, -3.5745e-01, -8.3873e-02, -1.5777e-01],
#         [ 1.1154e+00, -6.3402e-01,  2.4026e+00,  2.3404e+00,  3.8705e+00,
#           2.6721e+00, -1.2958e+00, -1.3577e+00, -1.3005e+00, -7.8384e-02,
#          -4.8150e-02,  4.2500e-01, -3.5745e-01, -8.3873e-02, -1.5777e-01],
#         [-3.6163e-01,  3.8273e-01, -4.8547e-01, -5.1334e-01, -3.6961e-01,
#          -6.7979e-01,  5.6496e-01,  5.4528e-01,  5.5048e-01, -7.8384e-02,
#          -4.8150e-02,  4.2500e-01, -3.5745e-01, -8.3873e-02, -1.5777e-01],
#         [-8.0157e-01,  1.8753e-01, -6.9767e-01, -3.7939e-01,  3.2219e-01,
#          -4.6575e-01, -2.4179e-01, -2.8240e-01, -2.4822e-01, -7.8384e-02,
#          -4.8150e-02,  4.2500e-01, -3.5745e-01, -8.3873e-02, -1.5777e-01],
#         [-1.2317e+00,  1.1853e+00, -9.1232e-01,  8.7677e-01,  9.7692e-01,
#           4.5393e-01, -8.5477e-01, -9.2898e-01, -8.4356e-01, -7.8384e-02,
#          -4.8150e-02,  4.2500e-01, -3.5745e-01, -8.3873e-02, -1.5777e-01],
#         [-6.3471e-01,  9.5085e-01, -5.8142e-01,  3.4890e-01,  1.6769e-01,
#          -3.6096e-03, -6.4409e-01, -7.2388e-01, -6.4791e-01, -7.8384e-02,
#          -4.8150e-02,  4.2500e-01, -3.5745e-01, -8.3873e-02, -1.5777e-01],
#         [-3.8857e-01,  2.2641e-01, -4.8194e-01, -1.7125e-01, -2.7739e-01,
#          -2.6474e-01, -4.2223e-01, -4.6578e-01, -4.2003e-01, -7.8384e-02,
#          -4.8150e-02,  4.2500e-01, -3.5745e-01, -8.3873e-02, -1.5777e-01],
#         [-8.0627e-01,  5.6990e-01, -9.5496e-01, -4.7569e-01, -4.3969e-01,
#          -7.1270e-01,  4.6250e-01,  4.6977e-01,  4.6822e-01, -7.8384e-02,
#          -4.8150e-02,  4.2500e-01, -3.5745e-01, -8.3873e-02, -1.5777e-01],
#         [ 7.2046e-01, -1.4032e+00,  4.9933e-01, -1.1547e+00, -6.7493e-01,
#          -6.5854e-01,  2.6288e+00,  2.5372e+00,  2.6465e+00, -7.8384e-02,
#          -4.8150e-02, -2.3530e+00, -3.5745e-01,  1.1923e+01, -1.5777e-01],
#         [ 2.7877e-01, -8.6450e-02,  1.3912e-01, -4.5694e-01, -4.2429e-01,
#          -4.4086e-01, -3.4147e-02,  1.9171e-01, -5.5930e-02, -7.8384e-02,
#          -4.8150e-02,  4.2500e-01, -3.5745e-01, -8.3873e-02, -1.5777e-01],
#         [ 1.6670e-01, -1.1296e-01,  1.8405e-02, -2.0672e-01, -4.4916e-01,
#          -1.7105e-01, -3.2613e-01, -2.8923e-01, -3.2026e-01, -7.8384e-02,
#          -4.8150e-02,  4.2500e-01, -3.5745e-01, -8.3873e-02, -1.5777e-01],
#         [-6.0315e-01, -5.8130e-02, -7.7318e-01,  1.3565e+00, -5.0629e-01,
#           1.4298e+00, -1.0759e+00, -1.1634e+00, -1.0711e+00, -7.8384e-02,
#          -4.8150e-02, -2.3530e+00,  2.7976e+00, -8.3873e-02, -1.5777e-01]])
# torch.Size([24, 15])
# tensor([[58.9200],
#         [29.4300],
#         [35.4800],
#         [54.8200],
#         [15.4300],
#         [60.9400],
#         [20.5300],
#         [27.3200],
#         [ 6.3200],
#         [68.1600],
#         [ 7.7100],
#         [23.3100],
#         [21.1400],
#         [ 5.6000],
#         [33.1900],
#         [24.1300],
#         [13.1000],
#         [16.2000],
#         [19.7200],
#         [34.6000],
#         [79.5300],
#         [24.2600],
#         [21.6700],
#         [ 8.2300]])

# %% [markdown]
# ## Modeling

# %%
class Zloc_Estimaotor(nn.Module):
    def __init__(self, input_dim, hidden_dim, layer_dim, output_dim=1):
        super().__init__()
        
        self.rnn = nn.LSTM(input_dim, hidden_dim, layer_dim, batch_first=True, bidirectional=False)
        
        #Layer
        layersize=[367, 164, 64]
        layerlist= []
        n_in=hidden_dim
        for i in layersize:
            layerlist.append(nn.Linear(n_in,i))
            layerlist.append(nn.ReLU())
            #layerlist.append(nn.BatchNorm1d(i))
            #layerlist.append(nn.Dropout(0.1))
            n_in=i           
        layerlist.append(nn.Linear(layersize[-1],1))
        #layerlist.append(nn.Sigmoid())
        
        self.fc=nn.Sequential(*layerlist)

        
    def forward(self, x):
        out, hn = self.rnn(x)
        output = self.fc(out[:,-1])
        return output

# %%
class Zloc_Estimaotor_s(nn.Module):
    def __init__(self, input_dim):
        super().__init__()
        
        #Layer
        layersize=[32,64,128,256,128,64,32]
        layerlist= []
        n_in=input_dim
        for i in layersize:
            layerlist.append(nn.Linear(n_in,i))
            layerlist.append(nn.ReLU())
            #layerlist.append(nn.BatchNorm1d(i))
            layerlist.append(nn.Dropout(0.1))
            n_in=i           
        layerlist.append(nn.Linear(layersize[-1],1))
        #layerlist.append(nn.Sigmoid())
        
        self.fc=nn.Sequential(*layerlist)

        
    def forward(self, x):
        #out, hn = self.rnn(x)
        output = self.fc(x)
        return output

# %% [markdown]
# ## Make  variable

# %%
import torch.nn.init as init
#def weight_init(m):
#    if isinstance(m, nn.Linear): # nn.Linear에 있는 가중치에만 적용
#        init.kaiming_uniform_(m.weight.data) # He initialization

# variable 
input_dim = val_length
hidden_dim = 674
layer_dim = 3
        
model = Zloc_Estimaotor(input_dim, hidden_dim, layer_dim)
#model = Zloc_Estimaotor_s(input_dim)
#model.apply(weight_init)
#loss_fn = nn.MSELoss()
loss_fn = nn.L1Loss()
optimizer = torch.optim.Adam(model.parameters(), lr=5e-3)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer,
                                                       factor=0.5,
                                                       patience = 10,
                                                       mode='min', # 우리는 낮아지는 값을 기대
                                                       verbose=True,
                                                       min_lr=1e-6)
from early_stopping import EarlyStopping
early_stopping = EarlyStopping(30, verbose=True)   

model.to(device)
# Out:
# Zloc_Estimaotor(
#   (rnn): LSTM(15, 674, num_layers=3, batch_first=True)
#   (fc): Sequential(
#     (0): Linear(in_features=674, out_features=367, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=367, out_features=164, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=164, out_features=64, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=64, out_features=1, bias=True)
#   )
# )

# %%
# train parameters
def count_parameter(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)
count_parameter(model) # 5686657
# Out:
# 9460838

# %% [markdown]
# ## Make Train, Valid function

# %%
def train(model, train_dataloader, idx_interval):
    model.train()
    
    train_loss = 0
    train_rmse = 0
    
    for idx, batch in enumerate(train_dataloader):
        optimizer.zero_grad()
        
        inp = batch[0].reshape(len(batch[0]),1,-1)
        
        prediction = model(inp.to(device))
        loss = loss_fn(prediction, batch[1].to(device)).cpu()
        
        # Backpropagation
        loss.backward()
        optimizer.step()
    
        train_loss += loss.item()
        if idx % idx_interval == 0:
            print("Train Epoch: {} [{}/{}] \t Train Loss(MAE): {:.4f} \t Train RMAE: {:.4f}".format(epoch, batch_sz*(idx+1), \
                                                                            len(train_dataloader)*batch_sz, \
                                                                            loss.item(), np.sqrt(loss.item())))
    
    train_loss /= len(train_dataloader)
    train_rmse = np.sqrt(train_loss)
        
    return train_loss, train_rmse

# %%
def evaluate(model, valid_dataloader):
    model.eval()
    
    valid_loss = 0
    valid_rmse = 0
    
    with torch.no_grad():
        for idx, batch in enumerate(valid_dataloader):
            inp = batch[0].reshape(len(batch[0]),1,-1)
            predictions = model(inp.to(device))
            loss = loss_fn(predictions, batch[1].to(device)).cpu()
            valid_loss += loss.item()
            
    valid_loss /= len(valid_dataloader)
    valid_rmse = np.sqrt(valid_loss)
    
    return valid_loss,valid_rmse

# %% [markdown]
# ## Train and Validation

# %%
Epoch = 500
best_mae = 99999
best_train_mae = 99999

train_mae_list = []
valid_mae_list = []


for epoch in range(1,(Epoch+1)):
    train_mae, train_rmae = train(model, train_dataloader, 200)
    valid_mae, valid_rmae = evaluate(model, valid_dataloader)

    print("[Epoch: {} \t Valid MAE: {:.4f}".format(epoch, valid_mae))
    print("[Epoch: {} \t Train MAE: {:.4f}".format(epoch, train_mae))
    
    scheduler.step(valid_mae)       
    # Save model
    if valid_mae < best_mae:
        path = "./weights/ODD_LSTM_BI_iou6.pth"
        torch.save(model.state_dict(), path) # 모델의 가중치만 저장 구조는 저장 x..?
        best_mae = valid_mae
        best_train_mae = train_mae
        
    train_mae_list.append(train_mae)
    valid_mae_list.append(valid_mae)
    
    early_stopping(valid_mae, model)
    if early_stopping.early_stop:
        print("Early stopping")
        break
# Out:
# EarlyStopping counter: 26 out of 30
# Train Epoch: 147 [24/21624] 	 Train Loss(MAE): 0.6048 	 Train RMAE: 0.7777
# Train Epoch: 147 [4824/21624] 	 Train Loss(MAE): 1.2080 	 Train RMAE: 1.0991
# Train Epoch: 147 [9624/21624] 	 Train Loss(MAE): 0.6111 	 Train RMAE: 0.7817
# Train Epoch: 147 [14424/21624] 	 Train Loss(MAE): 0.7188 	 Train RMAE: 0.8478
# Train Epoch: 147 [19224/21624] 	 Train Loss(MAE): 0.7335 	 Train RMAE: 0.8565
# [Epoch: 147 	 Valid MAE: 1.2288
# [Epoch: 147 	 Train MAE: 1.0339
# EarlyStopping counter: 27 out of 30
# Train Epoch: 148 [24/21624] 	 Train Loss(MAE): 1.6207 	 Train RMAE: 1.2731
# Train Epoch: 148 [4824/21624] 	 Train Loss(MAE): 1.1198 	 Train RMAE: 1.0582
# Train Epoch: 148 [9624/21624] 	 Train Loss(MAE): 0.6898 	 Train RMAE: 0.8306
# Train Epoch: 148 [14424/21624] 	 Train Loss(MAE): 0.8934 	 Train RMAE: 0.9452
# Train Epoch: 148 [19224/21624] 	 Train Loss(MAE): 1.5006 	 Train RMAE: 1.2250
# [Epoch: 148 	 Valid MAE: 1.2312
# [Epoch: 148 	 Train MAE: 1.0338
# EarlyStopping counter: 28 out of 30
# Train Epoch: 149 [24/21624] 	 Train Loss(MAE): 0.7328 	 Train RMAE: 0.8560
# Train Epoch: 149 [4824/21624] 	 Train Loss(MAE): 1.1163 	 Train RMAE: 1.0565
# Train Epoch: 149 [9624/21624] 	 Train Loss(MAE): 1.4465 	 Train RMAE: 1.2027
# Train Epoch: 149 [14424/21624] 	 Train Loss(MAE): 1.1633 	 Train RMAE: 1.0785
# Train Epoch: 149 [19224/21624] 	 Train Loss(MAE): 0.6932 	 Train RMAE: 0.8326
# [Epoch: 149 	 Valid MAE: 1.2314
# [Epoch: 149 	 Train MAE: 1.0340
# EarlyStopping counter: 29 out of 30
# Train Epoch: 150 [24/21624] 	 Train Loss(MAE): 1.4731 	 Train RMAE: 1.2137
# Train Epoch: 150 [4824/21624] 	 Train Loss(MAE): 1.0343 	 Train RMAE: 1.0170
# Train Epoch: 150 [9624/21624] 	 Train Loss(MAE): 1.1321 	 Train RMAE: 1.0640
# Train Epoch: 150 [14424/21624] 	 Train Loss(MAE): 1.0591 	 Train RMAE: 1.0291
# Train Epoch: 150 [19224/21624] 	 Train Loss(MAE): 0.6824 	 Train RMAE: 0.8261
# [Epoch: 150 	 Valid MAE: 1.2298
# [Epoch: 150 	 Train MAE: 1.0335
# EarlyStopping counter: 30 out of 30
# Early stopping

# %%
print('Valid best:',best_mae)
print('Train best:',best_train_mae)
# Out:
# Valid best: 1.2267018424726166
# Train best: 1.0477468611199108

# %% [markdown]
# # Epoch visualization

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(20,10))
ax1 = fig.add_subplot(1,1,1)
ax1.plot(train_mae_list, ls='-', color='blue', label='train')
ax1.set_ylim(0,5)

ax2 = ax1.twinx()
ax2.plot(valid_mae_list, ls='--', color='red', label='valid')
ax2.set_ylim(0,5)

ax1.set_title('MAE error')
ax1.legend(loc='upper right')
ax2.legend(loc='upper left')
plt.show()

# %%
# 가중치 가져오기
model = Zloc_Estimaotor(input_dim, hidden_dim,layer_dim)
model.load_state_dict(torch.load('./weights/ODD_LSTM_674_iou5.pth'))
model.eval()
model.to(device)
# Out:
# Zloc_Estimaotor(
#   (rnn): LSTM(15, 674, num_layers=3, batch_first=True)
#   (fc): Sequential(
#     (0): Linear(in_features=674, out_features=367, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=367, out_features=164, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=164, out_features=64, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=64, out_features=1, bias=True)
#   )
# )

# %% [markdown]
# # Predict Train

# %%
train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=len(df_train), shuffle=False)
for idx, batch in enumerate(train_dataloader):
    if idx == 1:
        break
    train_pred = batch[0]
predict_zloc = model(train_pred.reshape(-1,1,input_dim).to(device))

# %%
df_train['predict'] = predict_zloc.cpu().detach().numpy()
df_train[['zloc','predict']].head(10)
# Out:
#     zloc    predict
# 0  33.26  33.263603
# 1  44.06  44.198242
# 2  48.93  48.315491
# 3  53.00  50.919888
# 4  15.60  16.009462
# 5  35.56  35.006252
# 6  17.76  17.340387
# 7   6.08   6.002367
# 8  33.44  33.359352
# 9  20.77  20.318209

# %%
import numpy as np
abs0 = np.abs(df_train.zloc-df_train.predict)
abs0
# Out:
# 0        0.003603
# 1        0.138242
# 2        0.614509
# 3        2.080112
# 4        0.409462
#            ...
# 21611    0.300394
# 21612    0.672668
# 21613    0.344354
# 21614    5.283058
# 21615    1.924619
# Length: 21616, dtype: float64

# %%
sum(abs0/len(df_train))
# Out:
# 0.8699920306231775

# %%
np.mean(np.square(df_train['zloc']-df_train['predict']))**(1/2)
# Out:
# 1.6968547379538064

# %%
func = np.sum(np.abs((df_train.predict - df_train.zloc))/(df_train.predict))
men = func/len(df_train)
1-men
# Out:
# 0.9674491908614063

# %% [markdown]
# # Predict Valid

# %%
valid_dataloader = torch.utils.data.DataLoader(valid_dataset, batch_size=len(df_train), shuffle=False)
for idx, batch in enumerate(valid_dataloader):
    if idx == 1:
        break
    valid_pred = batch[0]
predict_zloc = model(valid_pred.reshape(-1,1,input_dim).to(device))

# %%
df_valid['predict'] = predict_zloc.cpu().detach().numpy()
df_valid[['zloc','predict']].head(10)
# Out:
#     zloc    predict
# 0  36.41  35.624786
# 1  37.96  36.356983
# 2  11.97  11.382937
# 3  41.95  44.205502
# 4  16.34  16.382841
# 5   4.65   4.894409
# 6  32.70  32.074898
# 7  42.93  43.279495
# 8  57.66  61.869606
# 9   9.71   8.501754

# %%
abs0 = np.abs(df_valid.zloc-df_valid.predict)
abs0
# Out:
# 0       0.785214
# 1       1.603017
# 2       0.587063
# 3       2.255502
# 4       0.042841
#           ...
# 2697    3.418585
# 2698    0.106542
# 2699    0.209877
# 2700    1.164662
# 2701    0.297951
# Length: 2702, dtype: float64

# %%
sum(abs0/len(df_valid))
# Out:
# 1.1637646065739502

# %%
np.mean(np.square(df_valid['zloc']-df_valid['predict']))**(1/2)
# Out:
# 2.0146947897061867

# %% [markdown]
# # Predict Test

# %%
test_mse, test_rmse = evaluate(model, test_dataloader)
print('Test MAE: {:4f} \t Test RMAE: {:4f}'.format(test_mse, test_rmse))
# Out:
# Test MAE: 1.232429 	 Test RMAE: 1.110148

# %%
# look dataset
for idx, batch in enumerate(test_dataloader):
    if idx == 1:
        break
    test_pred = batch[0]
predict_zloc = model(test_pred.reshape(-1,1,input_dim).to(device))

# %%
df_test['predict'] = predict_zloc.cpu().detach().numpy()
df_test[['zloc','predict']].head(10)
# Out:
#     zloc    predict
# 0  23.91  23.475006
# 1  22.08  21.985798
# 2  17.59  17.498339
# 3  15.68  16.178127
# 4  53.67  53.736671
# 5  14.61  14.598968
# 6   7.93   7.676457
# 7  26.44  27.472675
# 8  50.67  47.991505
# 9  56.22  59.372051

# %%
import numpy as np
abs0 = np.abs(df_test.zloc-df_test.predict)
abs0
# Out:
# 0       0.434994
# 1       0.094202
# 2       0.091661
# 3       0.498127
# 4       0.066671
#           ...
# 2698    1.508676
# 2699    0.247186
# 2700    0.841911
# 2701    0.599085
# 2702    0.239754
# Length: 2703, dtype: float64

# %%
sum(abs0/len(df_test))
# Out:
# 1.2324293322356759

# %%
np.mean(np.square(df_test['zloc']-df_test['predict']))**(1/2)
# Out:
# 2.198061344271634

# %%
func = np.sum(np.abs((df_test.predict - df_test.zloc))/(df_test.predict))
men = func/len(df_test)
1-men
# Out:
# 0.9493030624461511

# %% [markdown]
# ### 구간 나눠서 정확도 계산해보기

# %%
first = df_test[df_test['zloc']<=10]
func1 = np.sum(np.abs((first.predict - first.zloc))/(first.predict))
men1 = func1/len(first)
1-men1
# Out:
# 0.9180146743985739

# %%
mask = (df_test['zloc']>=10) & (df_test['zloc']<20)
second = df_test[mask]
func2 = np.sum(np.abs((second.predict - second.zloc))/(second.predict))
men2 = func2/len(second)
1-men2
# Out:
# 0.9605023942946158

# %%
mask = (df_test['zloc']>=20) & (df_test['zloc']<30)
third = df_test[mask]
func3 = np.sum(np.abs((third.predict - third.zloc))/(third.predict))
men3 = func3/len(third)
1-men3
# Out:
# 0.9594679391853635

# %%
mask = (df_test['zloc']>=30) & (df_test['zloc']<40)
fourth = df_test[mask]
func4 = np.sum(np.abs((fourth.predict - fourth.zloc))/(fourth.predict))
men4 = func4/len(fourth)
1-men4
# Out:
# 0.9542462783115824

# %%
mask = (df_test['zloc']>=40) & (df_test['zloc']<50)
fifth = df_test[mask]
func5 = np.sum(np.abs((fifth.predict - fifth.zloc))/(fifth.predict))
men5 = func5/len(fifth)
1-men5
# Out:
# 0.9533150674853343

# %%
mask = (df_test['zloc']>=50) & (df_test['zloc']<60)
sixth = df_test[mask]
func6 = np.sum(np.abs((sixth.predict - sixth.zloc))/(sixth.predict))
men6 = func6/len(sixth)
1-men6

# %% [markdown]
# # Visualization

# %%
df_train.plot(kind='scatter', x='zloc', y='depth_mean', marker='o', alpha=0.3, s=50, figsize=(20,10), color='blue')
plt.show()

# %%
df_train.plot(kind='scatter', x='predict', y='zloc', marker='o', alpha=0.3, s=50, figsize=(10,10), color='blue')
plt.show()

# %%
df_valid.plot(kind='scatter', x='predict', y='zloc', marker='o', alpha=0.3, s=50, figsize=(10,10), color='blue')
plt.show()

# %%
df_test.plot(kind='scatter', x='predict', y='zloc', marker='o', alpha=0.3, s=50, figsize=(10,10), color='blue')
# Out:
# <AxesSubplot:xlabel='predict', ylabel='zloc'>

# %%
z = df_train['zloc']
#print(z)

plt.style.use('ggplot')
df_train.plot(kind='scatter', x='predict', y='depth_mean', marker='o', cmap='viridis', c=z, alpha=0.5, s=50, 
              figsize=(30,10))
plt.xlabel('predict')
plt.title('predict-depth_mean')
plt.show()
